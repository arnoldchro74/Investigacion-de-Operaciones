# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero

# %% [markdown]
# # Boris Milkem Company

# %% [markdown]
# La empresa financiera de Boris Milkem posee seis activos. El precio de venta esperado (en millones de dólares) para cada activo es
# dado en la Tabla 32. Si el activo 1 se vende en el año 2, la empresa
# recibe 20 millones de dólares. Para mantener un flujo de caja regular,
# Milkem debe vender al menos 20 millones de dólares en activos durante el año
# 1, al menos $\$30$ millones durante el año 2, y al menos $\$35$
# millones durante el año 3. Establecer una IP que Milkem pueda usar para determinar cómo maximizar los ingresos totales de los activos
# vendidos durante los próximos tres años. Al implementar este modelo,
# ¿Cómo podría utilizarse la idea de un horizonte de planificación móvil?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
